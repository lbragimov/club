# %%
import random

sex = ["male", "female"]
skill = ["love", "can", "be able"]
music = ["hip-hop & rnb", "electrodance & house", "pop"]

def is_digit(string):
    if string.isdigit():
        return True
    else:
        print('The answer must be a positive integer')
        return False
            
def action(person_music, club_music):
    if person_music != club_music:
        print('drink vodka')
    else:
        if person_music == 'hip-hop & rnb' :
            print 'Swaying the body forward and backward, legs in a semi-squat, arms bent in\
                   elbows, head back and forth.'
        if person_music == 'electrodance & house' :
            print 'Swaying the body back and forth, there is almost no movement of the head,\
                   circular movements - rotation of hands, legs move in rhythm.'
        else :
            print 'Smooth movements of the body, arms, legs and head.'
    

class People:
    def __init__(self, sex, skill, music):
        self.sex = sex
        self.skill = skill
        self.music = music

crowd = 'zero'
while (is_digit(crowd) == False):
    print('How many people will go to the club?')
    crowd = raw_input()

crowd = int(crowd)
person = [People(random.choice(sex), random.choice(skill), random.choice(music)) for _ in range(crowd)]
    
for k in range(crowd):
    print("person[" + str(k + 1) + "]", person[k].sex, person[k].skill, person[k].music)

print(crowd)

amount_tracks = 'zero'
while (is_digit(amount_tracks) == False):
    print('How many tracks will play?')
    amount_tracks = raw_input()
    
amount_tracks = int(amount_tracks)
play_list = [random.choice(music) for _ in range(amount_tracks)]

print(play_list)

for n in range(amount_tracks):
    print(' ')
    print('Music is playing' + " " + play_list[n])
    for k in range(crowd):
        print("person[" + str(k + 1) + "]") 
        action(person[k].music, play_list[n])
        print(' ')
        print(n, k)
# Out:
# The answer must be a positive integer
# How many people will go to the club?
# 5
# ('person[1]', 'male', 'be able', 'electrodance & house')
# ('person[2]', 'female', 'can', 'pop')
# ('person[3]', 'female', 'be able', 'pop')
# ('person[4]', 'female', 'be able', 'hip-hop & rnb')
# ('person[5]', 'female', 'love', 'electrodance & house')
# 5
# The answer must be a positive integer
# How many tracks will play?
# 10
# ['hip-hop & rnb', 'hip-hop & rnb', 'electrodance & house', 'electrodance & house', 'hip-hop & rnb', 'hip-hop & rnb', 'hip-hop & rnb', 'electrodance & house', 'pop', 'pop']
#
# Music is playing hip-hop & rnb
# person[1]
# drink vodka
#
# (0, 0)
# person[2]
# drink vodka
#
# (0, 1)
# person[3]
# drink vodka
#
# (0, 2)
# person[4]
# Swaying the body forward and backward, legs in a semi-squat, arms bent in                   elbows, head back and forth.
# Smooth movements of the body, arms, legs and head.
#
# (0, 3)
# person[5]
# drink vodka
#
# (0, 4)
#
# ...
